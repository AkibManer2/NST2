# %%
# !install pip
# !pip install utils
import utils
# !pip install git+git://github.com/albertofernandezvillan/colaboratory-utils.git
# Out:
# install: missing destination file operand after 'pip'
# Try 'install --help' for more information.
# Requirement already satisfied: utils in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Collecting git+git://github.com/albertofernandezvillan/colaboratory-utils.git
#   Cloning git://github.com/albertofernandezvillan/colaboratory-utils.git to /tmp/pip-req-build-mqhlx506
#   Running command git clone --filter=blob:none --quiet git://github.com/albertofernandezvillan/colaboratory-utils.git /tmp/pip-req-build-mqhlx506
#   fatal: unable to connect to github.com:
#   github.com[0: 192.30.255.113]: errno=Connection timed out
#
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet git://github.com/albertofernandezvillan/colaboratory-utils.git /tmp/pip-req-build-mqhlx506 did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet git://github.com/albertofernandezvillan/colaboratory-utils.git /tmp/pip-req-build-mqhlx506 did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import utils.utils as utils
from utils.video_utils import create_video_from_intermediate_results

import torch
from torch.optim import Adam, LBFGS
from torch.autograd import Variable
import numpy as np
import os
import argparse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-51af26fb9b82> in <cell line: 1>()
# ----> 1 import utils.utils as utils
#       2 from utils.video_utils import create_video_from_intermediate_results
#       3
#       4 import torch
#       5 from torch.optim import Adam, LBFGS
#
# ModuleNotFoundError: No module named 'utils.utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
